# %%
# Import the dependencies.
import pandas as pd
import json
#import matplotlib.pyplot as plt
import numpy as np

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

#import gmaps and request
import requests
import gmaps

# Import API key
from config import g_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_des= city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Weather Description": city_des,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
                          
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | chokurdakh
# Processing Record 2 of Set 16 | lima
# Processing Record 3 of Set 16 | ushuaia
# Processing Record 4 of Set 16 | klaksvik
# Processing Record 5 of Set 16 | tasiilaq
# Processing Record 6 of Set 16 | shitanjing
# Processing Record 7 of Set 16 | korla
# Processing Record 8 of Set 16 | bluff
# Processing Record 9 of Set 16 | albany
# Processing Record 10 of Set 16 | valpoi
# Processing Record 11 of Set 16 | srednekolymsk
# Processing Record 12 of Set 16 | beyneu
# Processing Record 13 of Set 16 | rikitea
# Processing Record 14 of Set 16 | busselton
# Processing Record 15 of Set 16 | flinders
# Processing Record 16 of Set 16 | vestmanna
# Processing Record 17 of Set 16 | qaanaaq
# Processing Record 18 of Set 16 | muscat
# Processing Record 19 of Set 16 | victoria
# Processing Record 20 of Set 16 | hobart
# Processing Record 21 of Set 16 | castro
# Processing Record 22 of Set 16 | thompson
# Processing Record 23 of Set 16 | digha
# Processing Record 24 of Set 16 | fort erie
# Processing Record 25 of Set 16 | adrar
# Processing Record 26 of Set 16 | punta arenas
# Processing Record 27 of Set 16 | yellowknife
# Processing Record 28 of Set 16 | sao joao da barra
# Processing Record 29 of Set 16 | east london
# Processing Record 30 of Set 16 | bethel
# Processing Record 31 of Set 16 | saint-philippe
# Processing Record 32 of Set 16 | mar del plata
# Processing Record 33 of Set 16 | vaini
# Processing Record 34 of Set 16 | new norfolk
# Processing Record 35 of Set 16 | sioux lookout
# Processing Record 36 of Set 16 | aklavik
# Processing Record 37 of Set 16 | peleduy
# Processing Record 38 of Set 16 | atambua
# Processing Record 39 of Set 16 | atuona
# Processing Record 40 of Set 16 | hilo
# Processing Record 41 of Set 16 | sape
# Processing Record 42 of Set 16 | olafsvik
# Processing Record 43 of Set 16 | naftah
# City not found. Skipping...
# Processing Record 44 of Set 16 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 16 | kozhevnikovo
# Processing Record 46 of Set 16 | cherskiy
# Processing Record 47 of Set 16 | deer lake
# Processing Record 48 of Set 16 | san quintin
# Processing Record 49 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 16 | vao
# Processing Record 1 of Set 17 | bengkulu
# Processing Record 2 of Set 17 | lagoa
# Processing Record 3 of Set 17 | pontianak
# Processing Record 4 of Set 17 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 17 | christchurch
# Processing Record 6 of Set 17 | lebu
# Processing Record 7 of Set 17 | khash
# Processing Record 8 of Set 17 | mahon
# Processing Record 9 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 17 | rosarito
# Processing Record 12 of Set 17 | sao filipe
# Processing Record 13 of Set 17 | sao gabriel
# Processing Record 14 of Set 17 | portland
# Processing Record 15 of Set 17 | leningradskiy
# Processing Record 16 of Set 17 | westport
# Processing Record 17 of Set 17 | teknaf
# Processing Record 18 of Set 17 | mataura
# Processing Record 19 of Set 17 | san luis
# Processing Record 20 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 17 | barra do garcas
# Processing Record 22 of Set 17 | jamestown
# Processing Record 23 of Set 17 | faya
# Processing Record 24 of Set 17 | butaritari
# Processing Record 25 of Set 17 | ostrovnoy
# Processing Record 26 of Set 17 | chuy
# Processing Record 27 of Set 17 | port alfred
# Processing Record 28 of Set 17 | shu
# Processing Record 29 of Set 17 | puerto ayora
# Processing Record 30 of Set 17 | upernavik
# Processing Record 31 of Set 17 | uruguaiana
# Processing Record 32 of Set 17 | chapais
# Processing Record 33 of Set 17 | lerwick
# Processing Record 34 of Set 17 | yazykovo
# Processing Record 35 of Set 17 | rafraf
# Processing Record 36 of Set 17 | dikson
# Processing Record 37 of Set 17 | mount isa
# Processing Record 38 of Set 17 | grover beach
# Processing Record 39 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 17 | ust-nera
# Processing Record 41 of Set 17 | fort nelson
# Processing Record 42 of Set 17 | chifeng
# Processing Record 43 of Set 17 | henties bay
# Processing Record 44 of Set 17 | geraldton
# Processing Record 45 of Set 17 | arraial do cabo
# Processing Record 46 of Set 17 | udgir
# Processing Record 47 of Set 17 | puerto suarez
# Processing Record 48 of Set 17 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 17 | maragogi
# Processing Record 50 of Set 17 | saskylakh
# Processing Record 1 of Set 18 | sitka
# Processing Record 2 of Set 18 | zhangye
# Processing Record 3 of Set 18 | beringovskiy
# Processing Record 4 of Set 18 | ilulissat
# Processing Record 5 of Set 18 | nikolskoye
# Processing Record 6 of Set 18 | longyearbyen
# Processing Record 7 of Set 18 | kangaba
# Processing Record 8 of Set 18 | puro
# Processing Record 9 of Set 18 | khandyga
# Processing Record 10 of Set 18 | urulga
# City not found. Skipping...
# Processing Record 11 of Set 18 | luanda
# Processing Record 12 of Set 18 | honiara
# Processing Record 13 of Set 18 | basco
# Processing Record 14 of Set 18 | hearst
# Processing Record 15 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 18 | kodinsk
# Processing Record 17 of Set 18 | ambilobe
# Processing Record 18 of Set 18 | tuktoyaktuk
# Processing Record 19 of Set 18 | khatanga
# Processing Record 20 of Set 18 | cidreira
# Processing Record 21 of Set 18 | lata
# Processing Record 22 of Set 18 | inyonga
# Processing Record 23 of Set 18 | smithers
# Processing Record 24 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 18 | haines junction
# Processing Record 26 of Set 18 | kuldiga
# Processing Record 27 of Set 18 | saldanha
# Processing Record 28 of Set 18 | alugan
# Processing Record 29 of Set 18 | raymond terrace
# Processing Record 30 of Set 18 | hermanus
# Processing Record 31 of Set 18 | saint-paul
# Processing Record 32 of Set 18 | veraval
# Processing Record 33 of Set 18 | cape town
# Processing Record 34 of Set 18 | taoudenni
# Processing Record 35 of Set 18 | kushima
# Processing Record 36 of Set 18 | bredasdorp
# Processing Record 37 of Set 18 | port hardy
# Processing Record 38 of Set 18 | gien
# Processing Record 39 of Set 18 | ponta do sol
# Processing Record 40 of Set 18 | lakatoro
# Processing Record 41 of Set 18 | provideniya
# Processing Record 42 of Set 18 | havre-saint-pierre
# Processing Record 43 of Set 18 | san patricio
# Processing Record 44 of Set 18 | praia da vitoria
# Processing Record 45 of Set 18 | nalut
# Processing Record 46 of Set 18 | bambous virieux
# Processing Record 47 of Set 18 | patiya
# Processing Record 48 of Set 18 | pisco
# Processing Record 49 of Set 18 | chumikan
# Processing Record 50 of Set 18 | rabo de peixe
# Processing Record 1 of Set 19 | nome
# Processing Record 2 of Set 19 | kodiak
# Processing Record 3 of Set 19 | ballesteros
# Processing Record 4 of Set 19 | pevek
# Processing Record 5 of Set 19 | vila franca do campo
# Processing Record 6 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 19 | guerrero negro
# Processing Record 8 of Set 19 | sassandra
# Processing Record 9 of Set 19 | pangnirtung
# Processing Record 10 of Set 19 | lang son
# Processing Record 11 of Set 19 | kapaa
# Processing Record 12 of Set 19 | stephenville
# Processing Record 13 of Set 19 | telma
# Processing Record 14 of Set 19 | kruisfontein
# Processing Record 15 of Set 19 | jalu
# Processing Record 16 of Set 19 | central point
# Processing Record 17 of Set 19 | torbay
# Processing Record 18 of Set 19 | grindavik
# Processing Record 19 of Set 19 | gazli
# Processing Record 20 of Set 19 | waingapu
# Processing Record 21 of Set 19 | viedma
# Processing Record 22 of Set 19 | hithadhoo
# Processing Record 23 of Set 19 | ancud
# Processing Record 24 of Set 19 | ajaccio
# Processing Record 25 of Set 19 | itarema
# Processing Record 26 of Set 19 | planovskoye
# Processing Record 27 of Set 19 | randfontein
# Processing Record 28 of Set 19 | bonfim
# Processing Record 29 of Set 19 | misratah
# Processing Record 30 of Set 19 | barrow
# Processing Record 31 of Set 19 | cooma
# Processing Record 32 of Set 19 | higuey
# City not found. Skipping...
# Processing Record 33 of Set 19 | esperance
# Processing Record 34 of Set 19 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 19 | darnah
# Processing Record 36 of Set 19 | katsuura
# Processing Record 37 of Set 19 | hamilton
# Processing Record 38 of Set 19 | paamiut
# Processing Record 39 of Set 19 | bria
# Processing Record 40 of Set 19 | kloulklubed
# Processing Record 41 of Set 19 | jinchang
# Processing Record 42 of Set 19 | antsohihy
# Processing Record 43 of Set 19 | hailar
# Processing Record 44 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 19 | kuytun
# Processing Record 46 of Set 19 | bereda
# Processing Record 47 of Set 19 | fuling
# Processing Record 48 of Set 19 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 19 | gayny
# Processing Record 50 of Set 19 | bilma
# Processing Record 1 of Set 20 | constitucion
# Processing Record 2 of Set 20 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 20 | neiafu
# Processing Record 4 of Set 20 | zavyalovo
# Processing Record 5 of Set 20 | coquimbo
# Processing Record 6 of Set 20 | muisne
# Processing Record 7 of Set 20 | opuwo
# Processing Record 8 of Set 20 | qasigiannguit
# Processing Record 9 of Set 20 | changji
# Processing Record 10 of Set 20 | obo
# Processing Record 11 of Set 20 | carnarvon
# Processing Record 12 of Set 20 | lujan
# Processing Record 13 of Set 20 | totskoye
# Processing Record 14 of Set 20 | alta floresta
# Processing Record 15 of Set 20 | faanui
# Processing Record 16 of Set 20 | hasaki
# Processing Record 17 of Set 20 | rapid valley
# Processing Record 18 of Set 20 | khor
# Processing Record 19 of Set 20 | airai
# Processing Record 20 of Set 20 | cabo san lucas
# Processing Record 21 of Set 20 | savonlinna
# Processing Record 22 of Set 20 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 23 of Set 20 | lintangan
# Processing Record 24 of Set 20 | husavik
# Processing Record 25 of Set 20 | nanortalik
# Processing Record 26 of Set 20 | samalaeulu
# City not found. Skipping...
# Processing Record 27 of Set 20 | tiksi
# Processing Record 28 of Set 20 | inuvik
# Processing Record 29 of Set 20 | imeni poliny osipenko
# Processing Record 30 of Set 20 | tarakan
# Processing Record 31 of Set 20 | mahebourg
# Processing Record 32 of Set 20 | port elizabeth
# Processing Record 33 of Set 20 | cravo norte
# Processing Record 34 of Set 20 | tabiauea
# City not found. Skipping...
# Processing Record 35 of Set 20 | rognan
# Processing Record 36 of Set 20 | saint-pierre
# Processing Record 37 of Set 20 | port lincoln
# Processing Record 38 of Set 20 | flin flon
# Processing Record 39 of Set 20 | ipixuna
# Processing Record 40 of Set 20 | mezen
# Processing Record 41 of Set 20 | dunedin
# Processing Record 42 of Set 20 | ixtapa
# Processing Record 43 of Set 20 | umm lajj
# Processing Record 44 of Set 20 | baherden
# Processing Record 45 of Set 20 | coxim
# Processing Record 46 of Set 20 | bahia de caraquez
# Processing Record 47 of Set 20 | port blair
# Processing Record 48 of Set 20 | souillac
# Processing Record 49 of Set 20 | harper
# Processing Record 50 of Set 20 | antofagasta
# Processing Record 1 of Set 21 | talnakh
# Processing Record 2 of Set 21 | carbonia
# Processing Record 3 of Set 21 | helena
# Processing Record 4 of Set 21 | baruun-urt
# Processing Record 5 of Set 21 | ukiah
# Processing Record 6 of Set 21 | coihaique
# Processing Record 7 of Set 21 | umea
# Processing Record 8 of Set 21 | fortuna
# Processing Record 9 of Set 21 | tibiri
# Processing Record 10 of Set 21 | ribeira grande
# Processing Record 11 of Set 21 | kaitangata
# Processing Record 12 of Set 21 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 21 | tapes
# Processing Record 14 of Set 21 | togur
# Processing Record 15 of Set 21 | seydisehir
# Processing Record 16 of Set 21 | micheweni
# Processing Record 17 of Set 21 | avarua
# Processing Record 18 of Set 21 | launceston
# Processing Record 19 of Set 21 | cayenne
# Processing Record 20 of Set 21 | dalnerechensk
# Processing Record 21 of Set 21 | lavrentiya
# Processing Record 22 of Set 21 | kahului
# Processing Record 23 of Set 21 | katherine
# Processing Record 24 of Set 21 | ondarroa
# Processing Record 25 of Set 21 | cloquet
# Processing Record 26 of Set 21 | gornopravdinsk
# Processing Record 27 of Set 21 | codrington
# Processing Record 28 of Set 21 | floro
# Processing Record 29 of Set 21 | beira
# Processing Record 30 of Set 21 | san lazaro
# Processing Record 31 of Set 21 | liberty
# Processing Record 32 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 21 | saint george
# Processing Record 34 of Set 21 | kismayo
# Processing Record 35 of Set 21 | russkaya polyana
# Processing Record 36 of Set 21 | hami
# Processing Record 37 of Set 21 | kargalinskaya
# Processing Record 38 of Set 21 | tottori
# Processing Record 39 of Set 21 | lorengau
# Processing Record 40 of Set 21 | bowling green
# Processing Record 41 of Set 21 | tucumcari
# Processing Record 42 of Set 21 | tuatapere
# Processing Record 43 of Set 21 | sinnamary
# Processing Record 44 of Set 21 | verkhovazhye
# Processing Record 45 of Set 21 | tamasane
# Processing Record 46 of Set 21 | shingu
# Processing Record 47 of Set 21 | tabanan
# Processing Record 48 of Set 21 | chelyabinsk-40
# City not found. Skipping...
# Processing Record 49 of Set 21 | am timan
# Processing Record 50 of Set 21 | turukhansk
# Processing Record 1 of Set 22 | villaviciosa
# Processing Record 2 of Set 22 | meadow lake
# Processing Record 3 of Set 22 | tebingtinggi
# Processing Record 4 of Set 22 | dubbo
# Processing Record 5 of Set 22 | magistralnyy
# Processing Record 6 of Set 22 | kuche
# City not found. Skipping...
# Processing Record 7 of Set 22 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 22 | saint-joseph
# Processing Record 9 of Set 22 | oktyabrskoye
# Processing Record 10 of Set 22 | saint-augustin
# Processing Record 11 of Set 22 | georgetown
# Processing Record 12 of Set 22 | athabasca
# Processing Record 13 of Set 22 | aksay
# Processing Record 14 of Set 22 | yenagoa
# Processing Record 15 of Set 22 | syracuse
# Processing Record 16 of Set 22 | corinto
# Processing Record 17 of Set 22 | chhatapur
# Processing Record 18 of Set 22 | liverpool
# Processing Record 19 of Set 22 | tacna
# Processing Record 20 of Set 22 | sesvete
# Processing Record 21 of Set 22 | ishlei
# City not found. Skipping...
# Processing Record 22 of Set 22 | gravdal
# Processing Record 23 of Set 22 | farmington
# Processing Record 24 of Set 22 | dhidhdhoo
# Processing Record 25 of Set 22 | tautira
# Processing Record 26 of Set 22 | salta
# Processing Record 27 of Set 22 | narino
# Processing Record 28 of Set 22 | san cristobal
# Processing Record 29 of Set 22 | cam ranh
# Processing Record 30 of Set 22 | touros
# Processing Record 31 of Set 22 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 22 | roald
# Processing Record 33 of Set 22 | asfi
# Processing Record 34 of Set 22 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 22 | isangel
# Processing Record 36 of Set 22 | erdemli
# Processing Record 37 of Set 22 | minna
# Processing Record 38 of Set 22 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 22 | miyako
# Processing Record 40 of Set 22 | anadyr
# Processing Record 41 of Set 22 | kampong cham
# Processing Record 42 of Set 22 | rio grande
# Processing Record 43 of Set 22 | los llanos de aridane
# Processing Record 44 of Set 22 | gat
# Processing Record 45 of Set 22 | aden
# Processing Record 46 of Set 22 | huanuco
# Processing Record 47 of Set 22 | vardo
# Processing Record 48 of Set 22 | ajdabiya
# Processing Record 49 of Set 22 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 22 | severo-kurilsk
# Processing Record 1 of Set 23 | suntar
# Processing Record 2 of Set 23 | pauini
# Processing Record 3 of Set 23 | kirkenes
# Processing Record 4 of Set 23 | amga
# Processing Record 5 of Set 23 | abnub
# Processing Record 6 of Set 23 | naryan-mar
# Processing Record 7 of Set 23 | chara
# Processing Record 8 of Set 23 | vikhorevka
# Processing Record 9 of Set 23 | dingle
# Processing Record 10 of Set 23 | malumfashi
# Processing Record 11 of Set 23 | kaeo
# Processing Record 12 of Set 23 | huarmey
# Processing Record 13 of Set 23 | takoradi
# Processing Record 14 of Set 23 | eureka
# Processing Record 15 of Set 23 | havoysund
# Processing Record 16 of Set 23 | muyinga
# Processing Record 17 of Set 23 | calama
# Processing Record 18 of Set 23 | marsa matruh
# Processing Record 19 of Set 23 | labutta
# City not found. Skipping...
# Processing Record 20 of Set 23 | solnechnyy
# Processing Record 21 of Set 23 | ko samui
# Processing Record 22 of Set 23 | belmonte
# Processing Record 23 of Set 23 | tura
# Processing Record 24 of Set 23 | severo-yeniseyskiy
# Processing Record 25 of Set 23 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 23 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 23 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 23 | midland
# Processing Record 29 of Set 23 | morondava
# Processing Record 30 of Set 23 | grand gaube
# Processing Record 31 of Set 23 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 23 | cam pha
# City not found. Skipping...
# Processing Record 33 of Set 23 | kijang
# Processing Record 34 of Set 23 | temaraia
# City not found. Skipping...
# Processing Record 35 of Set 23 | casablanca
# Processing Record 36 of Set 23 | ahipara
# Processing Record 37 of Set 23 | damghan
# Processing Record 38 of Set 23 | visby
# Processing Record 39 of Set 23 | kupang
# Processing Record 40 of Set 23 | belyy yar
# Processing Record 41 of Set 23 | vysotsk
# Processing Record 42 of Set 23 | lincoln
# Processing Record 43 of Set 23 | luderitz
# Processing Record 44 of Set 23 | wadi maliz
# Processing Record 45 of Set 23 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 23 | vyazemskiy
# Processing Record 47 of Set 23 | meulaboh
# Processing Record 48 of Set 23 | hauterive
# Processing Record 49 of Set 23 | waldoboro
# Processing Record 50 of Set 23 | la ronge
# Processing Record 1 of Set 24 | obukhiv
# Processing Record 2 of Set 24 | khani
# Processing Record 3 of Set 24 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 24 | parnaiba
# Processing Record 5 of Set 24 | tigil
# Processing Record 6 of Set 24 | yulara
# Processing Record 7 of Set 24 | poronaysk
# Processing Record 8 of Set 24 | kenai
# Processing Record 9 of Set 24 | galgani
# City not found. Skipping...
# Processing Record 10 of Set 24 | manhattan
# Processing Record 11 of Set 24 | talas
# Processing Record 12 of Set 24 | mount gambier
# Processing Record 13 of Set 24 | lazaro cardenas
# Processing Record 14 of Set 24 | zaysan
# Processing Record 15 of Set 24 | juneau
# Processing Record 16 of Set 24 | vestmannaeyjar
# Processing Record 17 of Set 24 | te anau
# Processing Record 18 of Set 24 | port-gentil
# Processing Record 19 of Set 24 | aktau
# Processing Record 20 of Set 24 | griffith
# Processing Record 21 of Set 24 | kirakira
# Processing Record 22 of Set 24 | fare
# Processing Record 23 of Set 24 | kavieng
# Processing Record 24 of Set 24 | komsomolskiy
# Processing Record 25 of Set 24 | makakilo city
# Processing Record 26 of Set 24 | along
# Processing Record 27 of Set 24 | carauari
# Processing Record 28 of Set 24 | mouzouras
# Processing Record 29 of Set 24 | weston-super-mare
# Processing Record 30 of Set 24 | nouadhibou
# Processing Record 31 of Set 24 | natal
# Processing Record 32 of Set 24 | carroll
# Processing Record 33 of Set 24 | kalas
# Processing Record 34 of Set 24 | bandarbeyla
# Processing Record 35 of Set 24 | winton
# Processing Record 36 of Set 24 | glace bay
# Processing Record 37 of Set 24 | umm kaddadah
# Processing Record 38 of Set 24 | mae sai
# Processing Record 39 of Set 24 | gobabis
# Processing Record 40 of Set 24 | rodrigues alves
# Processing Record 41 of Set 24 | banda aceh
# Processing Record 42 of Set 24 | sheksna
# Processing Record 43 of Set 24 | birin
# Processing Record 44 of Set 24 | mokshan
# Processing Record 45 of Set 24 | mayo
# Processing Record 46 of Set 24 | kozhva
# Processing Record 47 of Set 24 | hovd
# Processing Record 48 of Set 24 | capoterra
# Processing Record 49 of Set 24 | brewster
# Processing Record 50 of Set 24 | ambon
# Processing Record 1 of Set 25 | salamiyah
# Processing Record 2 of Set 25 | zhezkazgan
# Processing Record 3 of Set 25 | severodvinsk
# Processing Record 4 of Set 25 | bathsheba
# Processing Record 5 of Set 25 | bassar
# Processing Record 6 of Set 25 | oudtshoorn
# Processing Record 7 of Set 25 | aligudarz
# Processing Record 8 of Set 25 | koumac
# Processing Record 9 of Set 25 | tarko-sale
# Processing Record 10 of Set 25 | ballina
# Processing Record 11 of Set 25 | agogo
# Processing Record 12 of Set 25 | andevoranto
# City not found. Skipping...
# Processing Record 13 of Set 25 | tsumeb
# Processing Record 14 of Set 25 | samarai
# Processing Record 15 of Set 25 | bantou
# Processing Record 16 of Set 25 | bayburt
# Processing Record 17 of Set 25 | dupnica
# City not found. Skipping...
# Processing Record 18 of Set 25 | lompoc
# Processing Record 19 of Set 25 | limulunga
# Processing Record 20 of Set 25 | college
# Processing Record 21 of Set 25 | ayacucho
# Processing Record 22 of Set 25 | ewa beach
# Processing Record 23 of Set 25 | avera
# Processing Record 24 of Set 25 | beavercreek
# Processing Record 25 of Set 25 | teahupoo
# Processing Record 26 of Set 25 | tamworth
# Processing Record 27 of Set 25 | tacoronte
# Processing Record 28 of Set 25 | marfino
# Processing Record 29 of Set 25 | shiyan
# Processing Record 30 of Set 25 | dubai
# Processing Record 31 of Set 25 | lundazi
# Processing Record 32 of Set 25 | paradwip
# City not found. Skipping...
# Processing Record 33 of Set 25 | yei
# Processing Record 34 of Set 25 | iguape
# Processing Record 35 of Set 25 | esso
# Processing Record 36 of Set 25 | danjiangkou
# Processing Record 37 of Set 25 | vanavara
# Processing Record 38 of Set 25 | sambava
# Processing Record 39 of Set 25 | asau
# Processing Record 40 of Set 25 | cortez
# Processing Record 41 of Set 25 | mahanoro
# Processing Record 42 of Set 25 | vestbygda
# City not found. Skipping...
# Processing Record 43 of Set 25 | bolonchen
# City not found. Skipping...
# Processing Record 44 of Set 25 | kazalinsk
# City not found. Skipping...
# Processing Record 45 of Set 25 | zhigalovo
# Processing Record 46 of Set 25 | dali
# Processing Record 47 of Set 25 | mongo
# Processing Record 48 of Set 25 | havelock
# Processing Record 49 of Set 25 | mabaruma
# Processing Record 50 of Set 25 | touliu
# City not found. Skipping...
# Processing Record 1 of Set 26 | tadine
# Processing Record 2 of Set 26 | los chiles
# Processing Record 3 of Set 26 | kulhudhuffushi
# Processing Record 4 of Set 26 | la rioja
# Processing Record 5 of Set 26 | chimbote
# Processing Record 6 of Set 26 | dalvik
# Processing Record 7 of Set 26 | sisophon
# Processing Record 8 of Set 26 | caraquet
# Processing Record 9 of Set 26 | andenes
# Processing Record 10 of Set 26 | changli
# Processing Record 11 of Set 26 | kropotkin
# Processing Record 12 of Set 26 | whitehorse
# Processing Record 13 of Set 26 | kita
# Processing Record 14 of Set 26 | senador guiomard
# Processing Record 15 of Set 26 | muroto
# Processing Record 16 of Set 26 | petropavlovsk-kamchatskiy
# Processing Record 17 of Set 26 | rio gallegos
# Processing Record 18 of Set 26 | abu dhabi
# Processing Record 19 of Set 26 | kwekwe
# Processing Record 20 of Set 26 | harnosand
# Processing Record 21 of Set 26 | katangli
# Processing Record 22 of Set 26 | vuktyl
# Processing Record 23 of Set 26 | torata
# Processing Record 24 of Set 26 | gillette
# Processing Record 25 of Set 26 | tarnos
# Processing Record 26 of Set 26 | kuito
# Processing Record 27 of Set 26 | lar gerd
# City not found. Skipping...
# Processing Record 28 of Set 26 | fernley
# Processing Record 29 of Set 26 | kendari
# Processing Record 30 of Set 26 | nishihara
# Processing Record 31 of Set 26 | igrim
# Processing Record 32 of Set 26 | miri
# Processing Record 33 of Set 26 | iqaluit
# Processing Record 34 of Set 26 | praxedis guerrero
# Processing Record 35 of Set 26 | birjand
# Processing Record 36 of Set 26 | gvardeysk
# Processing Record 37 of Set 26 | sorland
# Processing Record 38 of Set 26 | kavaratti
# Processing Record 39 of Set 26 | kudahuvadhoo
# Processing Record 40 of Set 26 | glendive
# Processing Record 41 of Set 26 | tornio
# Processing Record 42 of Set 26 | malamig
# Processing Record 43 of Set 26 | norman wells
# Processing Record 44 of Set 26 | sao gabriel da cachoeira
# Processing Record 45 of Set 26 | voh
# Processing Record 46 of Set 26 | oktyabrskiy
# Processing Record 47 of Set 26 | karratha
# Processing Record 48 of Set 26 | wanaka
# Processing Record 49 of Set 26 | gorin
# Processing Record 50 of Set 26 | daru
# Processing Record 1 of Set 27 | ginda
# Processing Record 2 of Set 27 | caravelas
# Processing Record 3 of Set 27 | sidi ali
# Processing Record 4 of Set 27 | hambantota
# Processing Record 5 of Set 27 | palamos
# Processing Record 6 of Set 27 | devils lake
# Processing Record 7 of Set 27 | nurota
# Processing Record 8 of Set 27 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 27 | srandakan
# Processing Record 10 of Set 27 | dukhovshchina
# Processing Record 11 of Set 27 | bitung
# Processing Record 12 of Set 27 | san juan
# Processing Record 13 of Set 27 | chabahar
# Processing Record 14 of Set 27 | chadiza
# Processing Record 15 of Set 27 | bocaranga
# City not found. Skipping...
# Processing Record 16 of Set 27 | kautokeino
# Processing Record 17 of Set 27 | ponorogo
# Processing Record 18 of Set 27 | shache
# Processing Record 19 of Set 27 | trapani
# Processing Record 20 of Set 27 | novo aripuana
# Processing Record 21 of Set 27 | alekseyevsk
# Processing Record 22 of Set 27 | jiguani
# Processing Record 23 of Set 27 | pecos
# Processing Record 24 of Set 27 | adeje
# Processing Record 25 of Set 27 | benguela
# Processing Record 26 of Set 27 | clyde river
# Processing Record 27 of Set 27 | shenjiamen
# Processing Record 28 of Set 27 | brindisi
# Processing Record 29 of Set 27 | riyadh
# Processing Record 30 of Set 27 | nantucket
# Processing Record 31 of Set 27 | graham
# Processing Record 32 of Set 27 | sahrak
# City not found. Skipping...
# Processing Record 33 of Set 27 | necochea
# Processing Record 34 of Set 27 | nchelenge
# Processing Record 35 of Set 27 | obihiro
# Processing Record 36 of Set 27 | saint-leu
# Processing Record 37 of Set 27 | champerico
# Processing Record 38 of Set 27 | mehamn
# Processing Record 39 of Set 27 | pachino
# Processing Record 40 of Set 27 | itainopolis
# Processing Record 41 of Set 27 | awjilah
# Processing Record 42 of Set 27 | soto la marina
# Processing Record 43 of Set 27 | minas
# Processing Record 44 of Set 27 | talcahuano
# Processing Record 45 of Set 27 | lyubech
# Processing Record 46 of Set 27 | kaura namoda
# Processing Record 47 of Set 27 | vrangel
# Processing Record 48 of Set 27 | macaboboni
# City not found. Skipping...
# Processing Record 49 of Set 27 | manbij
# Processing Record 50 of Set 27 | sao felix do xingu
# Processing Record 1 of Set 28 | rawson
# Processing Record 2 of Set 28 | kalmunai
# Processing Record 3 of Set 28 | leh
# Processing Record 4 of Set 28 | barceloneta
# Processing Record 5 of Set 28 | dongsheng
# Processing Record 6 of Set 28 | youkounkoun
# Processing Record 7 of Set 28 | acapulco
# Processing Record 8 of Set 28 | sembakung
# Processing Record 9 of Set 28 | litoral del san juan
# City not found. Skipping...
# Processing Record 10 of Set 28 | wageningen
# Processing Record 11 of Set 28 | yumen
# Processing Record 12 of Set 28 | strelka
# Processing Record 13 of Set 28 | ariquemes
# Processing Record 14 of Set 28 | chivolo
# Processing Record 15 of Set 28 | amposta
# Processing Record 16 of Set 28 | marawi
# Processing Record 17 of Set 28 | soderhamn
# Processing Record 18 of Set 28 | koshki
# Processing Record 19 of Set 28 | coruripe
# Processing Record 20 of Set 28 | kefar shemaryahu
# Processing Record 21 of Set 28 | rundu
# Processing Record 22 of Set 28 | cedar city
# Processing Record 23 of Set 28 | altay
# Processing Record 24 of Set 28 | lyngseidet
# Processing Record 25 of Set 28 | nicoya
# Processing Record 26 of Set 28 | pahrump
# Processing Record 27 of Set 28 | fayaoue
# Processing Record 28 of Set 28 | kibakwe
# Processing Record 29 of Set 28 | abha
# Processing Record 30 of Set 28 | chippenham
# Processing Record 31 of Set 28 | chicama
# Processing Record 32 of Set 28 | yurya
# City not found. Skipping...
# Processing Record 33 of Set 28 | hofn
# Processing Record 34 of Set 28 | charlestown
# Processing Record 35 of Set 28 | mokolo
# Processing Record 36 of Set 28 | turayf
# Processing Record 37 of Set 28 | bernardino de campos
# Processing Record 38 of Set 28 | monte azul paulista
# Processing Record 39 of Set 28 | burica
# City not found. Skipping...
# Processing Record 40 of Set 28 | new plymouth
# Processing Record 41 of Set 28 | zelenets
# Processing Record 42 of Set 28 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 28 | polunochnoye
# Processing Record 44 of Set 28 | aykhal
# Processing Record 45 of Set 28 | sorong
# Processing Record 46 of Set 28 | luganville
# Processing Record 47 of Set 28 | sisimiut
# Processing Record 48 of Set 28 | caraballeda
# Processing Record 49 of Set 28 | bongandanga
# Processing Record 50 of Set 28 | seoul
# Processing Record 1 of Set 29 | bratsk
# Processing Record 2 of Set 29 | gerede
# Processing Record 3 of Set 29 | sept-iles
# Processing Record 4 of Set 29 | pljevlja
# Processing Record 5 of Set 29 | saint-michel-des-saints
# Processing Record 6 of Set 29 | kenora
# Processing Record 7 of Set 29 | hong gai
# Processing Record 8 of Set 29 | bouza
# Processing Record 9 of Set 29 | ust-tsilma
# Processing Record 10 of Set 29 | tolon
# Processing Record 11 of Set 29 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 29 | pontes e lacerda
# Processing Record 13 of Set 29 | yeppoon
# Processing Record 14 of Set 29 | artyom
# Processing Record 15 of Set 29 | nemuro
# Processing Record 16 of Set 29 | cintalapa
# Processing Record 17 of Set 29 | butembo
# Processing Record 18 of Set 29 | aban
# Processing Record 19 of Set 29 | shambu
# Processing Record 20 of Set 29 | cangucu
# Processing Record 21 of Set 29 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 29 | katakwi
# Processing Record 23 of Set 29 | san policarpo
# Processing Record 24 of Set 29 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 29 | puerto escondido
# Processing Record 26 of Set 29 | qazvin
# Processing Record 27 of Set 29 | north bend
# Processing Record 28 of Set 29 | klyuchi
# Processing Record 29 of Set 29 | hay river
# Processing Record 30 of Set 29 | olinda
# Processing Record 31 of Set 29 | poum
# Processing Record 32 of Set 29 | dandong
# Processing Record 33 of Set 29 | henderson
# Processing Record 34 of Set 29 | sabha
# Processing Record 35 of Set 29 | kelapa sawit
# Processing Record 36 of Set 29 | alice springs
# Processing Record 37 of Set 29 | campoverde
# Processing Record 38 of Set 29 | bijela
# Processing Record 39 of Set 29 | luwuk
# Processing Record 40 of Set 29 | rumoi
# Processing Record 41 of Set 29 | belokurikha
# Processing Record 42 of Set 29 | pedra branca
# Processing Record 43 of Set 29 | yashkul
# Processing Record 44 of Set 29 | wellington
# Processing Record 45 of Set 29 | tsalka
# Processing Record 46 of Set 29 | sajanan
# Processing Record 47 of Set 29 | nancha
# Processing Record 48 of Set 29 | narsaq
# Processing Record 49 of Set 29 | saint-francois
# Processing Record 50 of Set 29 | jaciara
# Processing Record 1 of Set 30 | armenia
# Processing Record 2 of Set 30 | maldonado
# Processing Record 3 of Set 30 | jumla
# Processing Record 4 of Set 30 | rorvik
# Processing Record 5 of Set 30 | deputatskiy
# Processing Record 6 of Set 30 | comodoro rivadavia
# Processing Record 7 of Set 30 | tchibanga
# Processing Record 8 of Set 30 | pakxe
# Processing Record 9 of Set 30 | parlakimidi
# Processing Record 10 of Set 30 | douentza
# Processing Record 11 of Set 30 | inhambane
# Processing Record 12 of Set 30 | ravar
# Processing Record 13 of Set 30 | baykit
# Processing Record 14 of Set 30 | linhares
# Processing Record 15 of Set 30 | kochinda
# Processing Record 16 of Set 30 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 30 | general roca
# Processing Record 18 of Set 30 | panjab
# Processing Record 19 of Set 30 | swan hill
# Processing Record 20 of Set 30 | bilibino
# Processing Record 21 of Set 30 | paita
# Processing Record 22 of Set 30 | urusha
# Processing Record 23 of Set 30 | arman
# Processing Record 24 of Set 30 | muswellbrook
# Processing Record 25 of Set 30 | san joaquin
# Processing Record 26 of Set 30 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 27 of Set 30 | carrascal
# Processing Record 28 of Set 30 | kieta
# Processing Record 29 of Set 30 | mentok
# City not found. Skipping...
# Processing Record 30 of Set 30 | dwarka
# Processing Record 31 of Set 30 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 30 | yuli
# Processing Record 33 of Set 30 | rocha
# Processing Record 34 of Set 30 | awbari
# Processing Record 35 of Set 30 | kilrush
# Processing Record 36 of Set 30 | vanino
# Processing Record 37 of Set 30 | mogok
# Processing Record 38 of Set 30 | caninde de sao francisco
# Processing Record 39 of Set 30 | giddarbaha
# Processing Record 40 of Set 30 | moundou
# Processing Record 41 of Set 30 | xuddur
# Processing Record 42 of Set 30 | goderich
# Processing Record 43 of Set 30 | shimoda
# Processing Record 44 of Set 30 | gamba
# Processing Record 45 of Set 30 | hailey
# Processing Record 46 of Set 30 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 30 | davila
# Processing Record 48 of Set 30 | cervo
# Processing Record 49 of Set 30 | hit
# Processing Record 50 of Set 30 | bousse
# Processing Record 1 of Set 31 | bubaque
# Processing Record 2 of Set 31 | tairua
# Processing Record 3 of Set 31 | labuhan
# Processing Record 4 of Set 31 | yunyang
# Processing Record 5 of Set 31 | laguna
# Processing Record 6 of Set 31 | honningsvag
# Processing Record 7 of Set 31 | port hedland
# Processing Record 8 of Set 31 | broken hill
# Processing Record 9 of Set 31 | bonthe
# Processing Record 10 of Set 31 | aleksandrov gay
# Processing Record 11 of Set 31 | colares
# Processing Record 12 of Set 31 | montrose
# Processing Record 13 of Set 31 | ostersund
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City      Lat       Lng Weather Description  Max Temp  Humidity  \
# 0  Chokurdakh  70.6333  147.9167     overcast clouds    -16.91        86
# 1        Lima -12.0432  -77.0282           clear sky     68.90        76
# 2     Ushuaia -54.8000  -68.3000    scattered clouds     55.06        67
# 3    Klaksvik  62.2266   -6.5890     overcast clouds     40.12        91
# 4    Tasiilaq  65.6145  -37.6368       broken clouds     12.36        70
# 5  Shitanjing  39.2342  106.3439           clear sky     29.66        23
# 6       Korla  41.7597   86.1469           clear sky     28.20        46
# 7       Bluff -46.6000  168.3333     overcast clouds     67.80        75
# 8      Albany  42.6001  -73.9662     overcast clouds     20.26        69
# 9      Valpoi  15.5305   74.1356           clear sky     80.15        24
#
#    Cloudiness  Wind Speed Country                 Date
# 0          95        3.65      RU  2022-01-29 05:30:32
# 1           0        1.01      PE  2022-01-29 05:30:33
# 2          40        4.61      AR  2022-01-29 05:25:37
# 3         100       31.76      FO  2022-01-29 05:30:33
# 4          77        4.65      GL  2022-01-29 05:30:34
# 5           2        2.33      CN  2022-01-29 05:30:34
# 6           2        5.57      CN  2022-01-29 05:30:34
# 7          94        3.65      NZ  2022-01-29 05:30:35
# 8         100        3.00      US  2022-01-29 05:26:14
# 9          10        9.01      IN  2022-01-29 05:30:35

# %%
#reorder the column
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather Description"]

# %%
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Chokurdakh      RU  70.6333  147.9167    -16.91        86          95
# 1        Lima      PE -12.0432  -77.0282     68.90        76           0
# 2     Ushuaia      AR -54.8000  -68.3000     55.06        67          40
# 3    Klaksvik      FO  62.2266   -6.5890     40.12        91         100
# 4    Tasiilaq      GL  65.6145  -37.6368     12.36        70          77
# 5  Shitanjing      CN  39.2342  106.3439     29.66        23           2
# 6       Korla      CN  41.7597   86.1469     28.20        46           2
# 7       Bluff      NZ -46.6000  168.3333     67.80        75          94
# 8      Albany      US  42.6001  -73.9662     20.26        69         100
# 9      Valpoi      IN  15.5305   74.1356     80.15        24          10
#
#    Wind Speed Weather Description
# 0        3.65     overcast clouds
# 1        1.01           clear sky
# 2        4.61    scattered clouds
# 3       31.76     overcast clouds
# 4        4.65       broken clouds
# 5        2.33           clear sky
# 6        5.57           clear sky
# 7        3.65     overcast clouds
# 8        3.00     overcast clouds
# 9        9.01           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
